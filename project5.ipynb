# %%
import pandas as pd

# %%
dataset= pd.read_csv('marketing_data.csv')

# %%
dataset.isnull().any()
# Out:
# custumer_id         False
# purchase_date        True
# product_category    False
# amount_spend        False
# dtype: bool

# %%
dataset.dtypes
# Out:
# custumer_id          object
# purchase_date        object
# product_category     object
# amount_spend        float64
# dtype: object

# %%
dataset.head()
# Out:
#   custumer_id purchase_date product_category  amount_spend
# 0        C001    01/03/2023      Electronics        250.00
# 1        C002    02/03/2023            Books         45.50
# 2        C003   03/03/2023/      Home&Garden        150.75
# 3        C001    04/03/2023            Books         20.00
# 4        C002    05/03/2023      Electronics        525.00

# %%
dataset.tail()
# Out:
#   custumer_id purchase_date product_category  amount_spend
# 3        C001    04/03/2023            Books         20.00
# 4        C002    05/03/2023      Electronics        525.00
# 5        C004           NaN     Electronicts        399.99
# 6        C003           NaN            Books         10.50
# 7        C005    07/03/2023            Beuty         75.00

# %%
dataset.isnull()
# Out:
#    custumer_id  purchase_date  product_category  amount_spend
# 0        False          False             False         False
# 1        False          False             False         False
# 2        False          False             False         False
# 3        False          False             False         False
# 4        False          False             False         False
# 5        False           True             False         False
# 6        False           True             False         False
# 7        False          False             False         False

# %%
import pandas as pd
from datetime import datetime

class MarketingDataETL:
    def __init__(self):
        self.data = None

    def extract(self, file_path):
        self.data = pd.read_csv(file_path)
        return self.data

    def transform(self):
        # dropna untuk membuang baris yang salah satu isinya kosong
        self.data['purchase_date'] = pd.to_datetime(self.data['purchase_date'], errors='coerce')
        self.data = self.data.dropna().reset_index(drop=True)
        return self.data

    def store(self, transformed_data, store_path):
        transformed_data.to_csv(store_path, index=False)


etl = MarketingDataETL()
raw_data = etl.extract('marketing_data.csv')
transformed_data = etl.transform()
etl.store(transformed_data, 'cleaned_marketing_data.csv')

# %%
dataset= pd.read_csv('cleaned_marketing_data.csv')
dataset
# Out:
#   custumer_id purchase_date product_category  amount_spend
# 0        C001    2023-01-03      Electronics        250.00
# 1        C002    2023-02-03            Books         45.50
# 2        C003    2023-03-03      Home&Garden        150.75
# 3        C001    2023-04-03            Books         20.00
# 4        C002    2023-05-03      Electronics        525.00
# 5        C005    2023-07-03            Beuty         75.00

# %%
dataset.head()
# Out:
#   custumer_id purchase_date product_category  amount_spend
# 0        C001    2023-01-03      Electronics        250.00
# 1        C002    2023-02-03            Books         45.50
# 2        C003    2023-03-03      Home&Garden        150.75
# 3        C001    2023-04-03            Books         20.00
# 4        C002    2023-05-03      Electronics        525.00

# %%
dataset.tail()
# Out:
#   custumer_id purchase_date product_category  amount_spend
# 1        C002    2023-02-03            Books         45.50
# 2        C003    2023-03-03      Home&Garden        150.75
# 3        C001    2023-04-03            Books         20.00
# 4        C002    2023-05-03      Electronics        525.00
# 5        C005    2023-07-03            Beuty         75.00
